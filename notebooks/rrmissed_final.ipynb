# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
trash = pd.read_csv('trash_hauler_report.csv')
trash.head()
# Out:
#    Request Number Date Opened                              Request   \
# 0           25270    11/01/17                      Trash - Backdoor
# 1           25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2           25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3           25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4           25312    11/01/17  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 old matthews rd
# 4                  Missed the even side of the road.          604 croley dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# 0   37207.0    RED RIVER        3205               2.0  1.727970e+06
# 1   37218.0    RED RIVER        4202               1.0  1.721259e+06
# 2   37209.0    RED RIVER        4205              20.0  1.707027e+06
# 3   37207.0    WASTE IND        2206               2.0  1.735692e+06
# 4   37209.0    RED RIVER        4203              20.0  1.710186e+06
#
#     State Plan Y
# 0  686779.478089
# 1  685444.799565
# 2  659887.471571
# 3  685027.245923
# 4  664205.101066

# %%
trash.columns = trash.columns.str.strip()
trash['Zip Code'] = trash['Zip Code'].astype('Int64').astype(str).str.zfill(5)
trash = trash[trash['Request'] != 'Damage to Property']

missed_categories = ['Trash - Backdoor', 'Trash - Curbside/Alley Missed Pickup']

pattern = r"\bmiss\w*\b|not\s+emptied|not\s+picked\s+up|no\s+pick\s+up" #miss/missed, not emptied, not picked up, no pick up

if isinstance(missed_categories, list):
    missed_pattern = '|'.join(missed_categories)
else:
    missed_pattern = missed_categories 

rrmissed = trash[
    (trash['Trash Hauler'].str.contains("Red River", case=False, na=False)) &
    (
        (trash['Request'].str.contains(missed_pattern, case=False, na=False)) |
        (trash['Description'].str.contains(pattern, case=False, na=False))
    )
]

rrmissed = rrmissed.dropna(subset = ['Incident Address']) # drop known missing address

# rrmissed = rrmissed.drop_duplicates(subset=['Incident Address', 'Date Opened']) # I believe this is redundancy and is taken care of later

def normalize_address(s: str) -> str:
    if pd.isna(s):
        return s
    # Only keep everything before the first comma
    s = s.split(",")[0]
    s = s.upper()
    s = re.sub(r"[.,]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    # (keep the direction/street type replacements here)
    return s

rrmissed["address_norm"] = rrmissed["Incident Address"].apply(normalize_address)

rrmissed["Date Opened"] = pd.to_datetime(rrmissed["Date Opened"], errors="coerce")
rrmissed["date_only"] = rrmissed["Date Opened"].dt.date

rrmissed_dedup = (
    rrmissed.sort_values(['address_norm', 'date_only', 'Date Opened'])
    .drop_duplicates(subset=['address_norm', 'date_only'], keep='first')
    .reset_index(drop=True)
)

gap = rrmissed_dedup.groupby("address_norm")["Date Opened"].diff().dt.days
rrmissed_dedup["new_event"] = (gap.isna()) | (gap > 6)
rrmissed_dedup["event_id"]  = rrmissed_dedup.groupby("address_norm")["new_event"].cumsum()

grp = rrmissed_dedup.groupby(['address_norm', "event_id"])['Date Opened']
rrmissed_dedup["event_date"]     = grp.transform("min")     

rrmissed_dedup["event_seq"] = rrmissed_dedup["event_id"].astype("Int64")

rrmissed_dedup["fine_event"] = (rrmissed_dedup["event_seq"] > 1).astype(int) * 200

rrmissed_dedup["first_event"] = (rrmissed_dedup['Date Opened'] == rrmissed_dedup["event_date"])
rrmissed_dedup["fine_event"] = rrmissed_dedup["fine_event"].where(rrmissed_dedup["first_event"], 0)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_39640\2230562832.py:39: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   rrmissed["Date Opened"] = pd.to_datetime(rrmissed["Date Opened"], errors="coerce")

# %%
rrmissed_dedup
# Out:
#        Request Number Date Opened                               Request  \
# 0              155122  2019-03-15  Trash - Curbside/Alley Missed Pickup
# 1               52252  2018-03-07  Trash - Curbside/Alley Missed Pickup
# 2              121431  2018-12-05  Trash - Curbside/Alley Missed Pickup
# 3               30424  2017-11-28  Trash - Curbside/Alley Missed Pickup
# 4              142247  2019-02-14  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 13125          192335  2019-05-31  Trash - Curbside/Alley Missed Pickup
# 13126          133573  2019-01-23  Trash - Curbside/Alley Missed Pickup
# 13127           25809  2017-11-02  Trash - Curbside/Alley Missed Pickup
# 13128          256189  2019-10-07  Trash - Curbside/Alley Missed Pickup
# 13129          232129  2019-08-15  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 0                                                   MISS
# 1                                          Missed- trash
# 2                                          Missed- trash
# 3                                         missed pick up
# 4      Trash was not collected from any customers on ...
# ...                                                  ...
# 13125            odd # side of street was not picked up.
# 13126                        got only one side of street
# 13127                         Robin Springs Road missed!
# 13128                                 this street missed
# 13129                                               miss
#
#                                         Incident Address Zip Code  \
# 0      100 Bluefield Square, Nashville, TN 37214, Uni...    37214
# 1                                    100 Braxton Hill Ct    37204
# 2                                    100 Brook Hollow Rd    37205
# 3                                       100 cedarmont ct    37211
# 4      100 Clydelan Ct, Nashville, TN 37205, United S...    37205
# ...                                                  ...      ...
# 13125         Old Tusculum Rd, Antioch, Tennessee, 37013    37013
# 13126      Queens Ln, Nashville, TN 37218, United States    37218
# 13127                                   Robin Springs Rd    37220
# 13128     Trevino Pl, Nashville, TN 37013, United States    37013
# 13129    Westboro Dr, Nashville, TN 37209, United States    37209
#
#       Trash Hauler Trash Route  Council District  State Plan X   State Plan Y  \
# 0        RED RIVER        1505              15.0  1.770431e+06  666861.601362
# 1        RED RIVER       3302S              25.0  1.733781e+06  640909.303557
# 2        RED RIVER        1303              23.0  1.708043e+06  642454.642918
# 3        RED RIVER        4403              31.0  1.760265e+06  622441.107959
# 4        RED RIVER        1302              34.0  1.710255e+06  640390.616149
# ...            ...         ...               ...           ...            ...
# 13125    RED RIVER        4404              30.0  1.763332e+06  626852.263728
# 13126    RED RIVER        3203               1.0  1.714591e+06  686127.550777
# 13127    RED RIVER       3302S              34.0  1.732450e+06  639784.397978
# 13128    RED RIVER        3505              29.0  1.785940e+06  636624.255256
# 13129    RED RIVER        4203              20.0  1.710106e+06  662979.800016
#
#                address_norm   date_only  new_event  event_id event_date  \
# 0      100 BLUEFIELD SQUARE  2019-03-15       True         1 2019-03-15
# 1       100 BRAXTON HILL CT  2018-03-07       True         1 2018-03-07
# 2       100 BROOK HOLLOW RD  2018-12-05       True         1 2018-12-05
# 3          100 CEDARMONT CT  2017-11-28       True         1 2017-11-28
# 4           100 CLYDELAN CT  2019-02-14       True         1 2019-02-14
# ...                     ...         ...        ...       ...        ...
# 13125       OLD TUSCULUM RD  2019-05-31       True         1 2019-05-31
# 13126             QUEENS LN  2019-01-23       True         1 2019-01-23
# 13127      ROBIN SPRINGS RD  2017-11-02       True         1 2017-11-02
# 13128            TREVINO PL  2019-10-07       True         1 2019-10-07
# 13129           WESTBORO DR  2019-08-15       True         1 2019-08-15
#
#        event_seq  fine_event  first_event
# 0              1           0         True
# 1              1           0         True
# 2              1           0         True
# 3              1           0         True
# 4              1           0         True
# ...          ...         ...          ...
# 13125          1           0         True
# 13126          1           0         True
# 13127          1           0         True
# 13128          1           0         True
# 13129          1           0         True
#
# [13130 rows x 19 columns]

# %%
rrmissed_final = rrmissed_dedup[rrmissed_dedup['new_event'] == True]

# %%
rrmissed_final
# Out:
#        Request Number Date Opened                               Request  \
# 0              155122  2019-03-15  Trash - Curbside/Alley Missed Pickup
# 1               52252  2018-03-07  Trash - Curbside/Alley Missed Pickup
# 2              121431  2018-12-05  Trash - Curbside/Alley Missed Pickup
# 3               30424  2017-11-28  Trash - Curbside/Alley Missed Pickup
# 4              142247  2019-02-14  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 13125          192335  2019-05-31  Trash - Curbside/Alley Missed Pickup
# 13126          133573  2019-01-23  Trash - Curbside/Alley Missed Pickup
# 13127           25809  2017-11-02  Trash - Curbside/Alley Missed Pickup
# 13128          256189  2019-10-07  Trash - Curbside/Alley Missed Pickup
# 13129          232129  2019-08-15  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# 0                                                   MISS
# 1                                          Missed- trash
# 2                                          Missed- trash
# 3                                         missed pick up
# 4      Trash was not collected from any customers on ...
# ...                                                  ...
# 13125            odd # side of street was not picked up.
# 13126                        got only one side of street
# 13127                         Robin Springs Road missed!
# 13128                                 this street missed
# 13129                                               miss
#
#                                         Incident Address Zip Code  \
# 0      100 Bluefield Square, Nashville, TN 37214, Uni...    37214
# 1                                    100 Braxton Hill Ct    37204
# 2                                    100 Brook Hollow Rd    37205
# 3                                       100 cedarmont ct    37211
# 4      100 Clydelan Ct, Nashville, TN 37205, United S...    37205
# ...                                                  ...      ...
# 13125         Old Tusculum Rd, Antioch, Tennessee, 37013    37013
# 13126      Queens Ln, Nashville, TN 37218, United States    37218
# 13127                                   Robin Springs Rd    37220
# 13128     Trevino Pl, Nashville, TN 37013, United States    37013
# 13129    Westboro Dr, Nashville, TN 37209, United States    37209
#
#       Trash Hauler Trash Route  Council District  State Plan X   State Plan Y  \
# 0        RED RIVER        1505              15.0  1.770431e+06  666861.601362
# 1        RED RIVER       3302S              25.0  1.733781e+06  640909.303557
# 2        RED RIVER        1303              23.0  1.708043e+06  642454.642918
# 3        RED RIVER        4403              31.0  1.760265e+06  622441.107959
# 4        RED RIVER        1302              34.0  1.710255e+06  640390.616149
# ...            ...         ...               ...           ...            ...
# 13125    RED RIVER        4404              30.0  1.763332e+06  626852.263728
# 13126    RED RIVER        3203               1.0  1.714591e+06  686127.550777
# 13127    RED RIVER       3302S              34.0  1.732450e+06  639784.397978
# 13128    RED RIVER        3505              29.0  1.785940e+06  636624.255256
# 13129    RED RIVER        4203              20.0  1.710106e+06  662979.800016
#
#                address_norm   date_only  new_event  event_id event_date  \
# 0      100 BLUEFIELD SQUARE  2019-03-15       True         1 2019-03-15
# 1       100 BRAXTON HILL CT  2018-03-07       True         1 2018-03-07
# 2       100 BROOK HOLLOW RD  2018-12-05       True         1 2018-12-05
# 3          100 CEDARMONT CT  2017-11-28       True         1 2017-11-28
# 4           100 CLYDELAN CT  2019-02-14       True         1 2019-02-14
# ...                     ...         ...        ...       ...        ...
# 13125       OLD TUSCULUM RD  2019-05-31       True         1 2019-05-31
# 13126             QUEENS LN  2019-01-23       True         1 2019-01-23
# 13127      ROBIN SPRINGS RD  2017-11-02       True         1 2017-11-02
# 13128            TREVINO PL  2019-10-07       True         1 2019-10-07
# 13129           WESTBORO DR  2019-08-15       True         1 2019-08-15
#
#        event_seq  fine_event  first_event
# 0              1           0         True
# 1              1           0         True
# 2              1           0         True
# 3              1           0         True
# 4              1           0         True
# ...          ...         ...          ...
# 13125          1           0         True
# 13126          1           0         True
# 13127          1           0         True
# 13128          1           0         True
# 13129          1           0         True
#
# [12529 rows x 19 columns]

# %%
total_fines = int(rrmissed_final["fine_event"].sum())
unique_events = int(
    rrmissed_final[rrmissed_final['event_id'] != 1].drop_duplicates(['address_norm', "event_id"]).shape[0]
)

# %%
total_fines
# Out:
# 827400

# %%
unique_events
# Out:
# 4137

# %%
rrmissed_final.to_csv('rrmissed_final.csv', index = False)

# %%
rrmissed_final_fined = rrmissed_final[rrmissed_final['fine_event'] != 0]

# %%
rrmissed_final_fined
# Out:
#        Request Number Date Opened                               Request  \
# 11             219376  2019-07-23  Trash - Curbside/Alley Missed Pickup
# 15             216148  2019-07-17  Trash - Curbside/Alley Missed Pickup
# 17             256932  2019-10-09  Trash - Curbside/Alley Missed Pickup
# 25             169354  2019-04-15  Trash - Curbside/Alley Missed Pickup
# 27             233815  2019-08-19  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 13096          126743  2018-12-31            Trash Collection Complaint
# 13098           81230  2018-07-08  Trash - Curbside/Alley Missed Pickup
# 13104          235738  2019-08-21  Trash - Curbside/Alley Missed Pickup
# 13109          212542  2019-07-10  Trash - Curbside/Alley Missed Pickup
# 13112           60997  2018-04-17                      Trash - Backdoor
#
#                                              Description  \
# 11                                     continuous misses
# 15     Curb trash/missed Tuesday Dead end street. Che...
# 17                                          missed trash
# 25                                          missed trash
# 27                        EVERYONE'S TRASH IS STILL OUT.
# ...                                                  ...
# 13096  Trash/never does cart gets pickup on Wednesday...
# 13098      Our neighbors cans were emptied but not ours.
# 13104                                               miss
# 13109                                               miss
# 13112                                     missed pick up
#
#                                         Incident Address Zip Code  \
# 11     100 Nashboro Greens, Nashville, TN 37217, Unit...    37217
# 15      100 Rhine Dr, Nashville, TN 37115, United States    37115
# 17                            100 S GRAYCROFT AVE, 37115    37115
# 25     1000 Flintlock Ct, Nashville, TN 37217, United...    37217
# 27            1000 Trevino Pl, Antioch, Tennessee, 37013    37013
# ...                                                  ...      ...
# 13096  960 44th Ave N, Nashville, TN 37209, United St...    37209
# 13098                                     960 battery ln    37220
# 13104  971 Windrowe Dr, Nashville, TN 37205, United S...    37205
# 13109  986 Malquin Dr, Nashville, TN 37216, United St...    37216
# 13112                                      998 shadow ln    37206
#
#       Trash Hauler Trash Route  Council District  State Plan X   State Plan Y  \
# 11       RED RIVER        2505              29.0  1.778871e+06  640860.298135
# 15       RED RIVER        3212               8.0  1.750466e+06  703800.798806
# 17       RED RIVER        3214               8.0  1.752490e+06  703450.683280
# 25       RED RIVER        2505              29.0  1.780096e+06  638311.436050
# 27       RED RIVER        3505              29.0  1.785843e+06  636907.168793
# ...            ...         ...               ...           ...            ...
# 13096    RED RIVER        1309              20.0  1.720477e+06  666161.601824
# 13098    RED RIVER        3302              25.0  1.735063e+06  639880.770427
# 13104    RED RIVER        1301              23.0  1.701565e+06  650680.391888
# 13109    RED RIVER        2204               8.0  1.753519e+06  691299.198896
# 13112    RED RIVER        1203               6.0  1.759942e+06  675175.528480
#
#               address_norm   date_only  new_event  event_id event_date  \
# 11     100 NASHBORO GREENS  2019-07-23       True         2 2019-07-23
# 15            100 RHINE DR  2019-07-17       True         2 2019-07-17
# 17     100 S GRAYCROFT AVE  2019-10-09       True         2 2019-10-09
# 25       1000 FLINTLOCK CT  2019-04-15       True         2 2019-04-15
# 27         1000 TREVINO PL  2019-08-19       True         2 2019-08-19
# ...                    ...         ...        ...       ...        ...
# 13096       960 44TH AVE N  2018-12-31       True         4 2018-12-31
# 13098       960 BATTERY LN  2018-07-08       True         2 2018-07-08
# 13104      971 WINDROWE DR  2019-08-21       True         2 2019-08-21
# 13109       986 MALQUIN DR  2019-07-10       True         2 2019-07-10
# 13112        998 SHADOW LN  2018-04-17       True         2 2018-04-17
#
#        event_seq  fine_event  first_event
# 11             2         200         True
# 15             2         200         True
# 17             2         200         True
# 25             2         200         True
# 27             2         200         True
# ...          ...         ...          ...
# 13096          4         200         True
# 13098          2         200         True
# 13104          2         200         True
# 13109          2         200         True
# 13112          2         200         True
#
# [4137 rows x 19 columns]

# %%
rrmissed_final_fined.to_csv('rrmissed_final_fined.csv', index = False)

# %% [markdown]
# ## Plotting

# %%
missed_by_zip = rrmissed_final['Zip Code'].value_counts().head(10)

ax = missed_by_zip.plot(kind="bar", figsize=(10,5), title="Top 10 Zip Codes with Most Missed Pickups")
ax.set_xlabel("")                 # hide the x-axis label ("Zip Code")
ax.tick_params(axis="x", labelrotation=45)
plt.tight_layout()

plt.savefig('top_10_missed_rr.png')

plt.show()

# %%
fines_only = rrmissed_final[rrmissed_final['fine_event'] != 0]
fine_costs = fines_only.groupby(fines_only['event_date'].dt.to_period("M"))['fine_event'].sum()

ax = fine_costs.plot(kind="line", figsize=(10,5), title="Red River Total Fine Events Over Time", color="red")
ax.set_xlabel("")           # remove x-axis label
plt.tight_layout()

plt.savefig('total_fine_events_rr.png')

plt.show()

# %%
fine_costs.head()
# Out:
# event_date
# 2017-11     4200
# 2017-12     5000
# 2018-01     8000
# 2018-02    12800
# 2018-03    16200
# Freq: M, Name: fine_event, dtype: int64

# %%
missed_over_time = rrmissed_final.groupby(rrmissed_final['event_date'].dt.to_period("M")).size()

ax = missed_over_time.plot(kind="line", figsize=(10,5), title="Red River Missed Pickups Over Time")
ax.set_xlabel("")           # remove x-axis label
plt.tight_layout()

plt.savefig('rr_missed_pickups_over_time.png')

plt.show()

# %%
missed_over_time.head()
# Out:
# event_date
# 2017-11    306
# 2017-12    241
# 2018-01    335
# 2018-02    323
# 2018-03    310
# Freq: M, dtype: int64

# %%
address_counts = rrmissed_final.groupby("address_norm").size()
chronic_addresses = address_counts[address_counts > 1]
chronic_addresses.plot(
    kind="hist",
    bins=range(2, chronic_addresses.max()+2),  # start at 2 misses
    figsize=(10,5),
    edgecolor="black",
    title="Distribution of Addresses with >1 Missed Pickup"
)

plt.ylabel("")
plt.show()

# %%
rrmissed_final['event_date'] = pd.to_datetime(rrmissed_final['event_date'])
fines_by_month = (
    rrmissed_final[rrmissed_final['fine_event'] != 0]
    .groupby(rrmissed_final['event_date'].dt.to_period("M"))['fine_event']
    .count()
    .reset_index(name="Fine Events")
)

fines_by_month["Fines Owed ($)"] = fines_by_month["Fine Events"] * 200
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7160\1574603206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rrmissed_final['event_date'] = pd.to_datetime(rrmissed_final['event_date'])

# %%
# Out:
#    event_date  Fine Events  Fines Owed ($)
# 0     2017-11           21            4200
# 1     2017-12           25            5000
# 2     2018-01           40            8000
# 3     2018-02           64           12800
# 4     2018-03           81           16200
# 5     2018-04           92           18400
# 6     2018-05           80           16000
# 7     2018-06           69           13800
# 8     2018-07           92           18400
# 9     2018-08          117           23400
# 10    2018-09           92           18400
# 11    2018-10           89           17800
# 12    2018-11           94           18800
# 13    2018-12          104           20800
# 14    2019-01          196           39200
# 15    2019-02          245           49000
# 16    2019-03          250           50000
# 17    2019-04          214           42800
# 18    2019-05          283           56600
# 19    2019-06          318           63600
# 20    2019-07          285           57000
# 21    2019-08          513          102600
# 22    2019-09          248           49600
# 23    2019-10          511          102200
# 24    2019-11           14            2800
