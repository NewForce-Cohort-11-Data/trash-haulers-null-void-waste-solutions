# %%
import pandas as pd
import numpy as np
import re

# %%
trash = pd.read_csv('trash_hauler_report.csv')
trash.head()
# Out:
#    Request Number Date Opened                              Request   \
# 0           25270    11/01/17                      Trash - Backdoor
# 1           25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2           25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3           25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4           25312    11/01/17  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 old matthews rd
# 4                  Missed the even side of the road.          604 croley dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# 0   37207.0    RED RIVER        3205               2.0  1.727970e+06
# 1   37218.0    RED RIVER        4202               1.0  1.721259e+06
# 2   37209.0    RED RIVER        4205              20.0  1.707027e+06
# 3   37207.0    WASTE IND        2206               2.0  1.735692e+06
# 4   37209.0    RED RIVER        4203              20.0  1.710186e+06
#
#     State Plan Y
# 0  686779.478089
# 1  685444.799565
# 2  659887.471571
# 3  685027.245923
# 4  664205.101066

# %%
trash.columns = trash.columns.str.strip()
trash['Zip Code'] = trash['Zip Code'].astype('Int64').astype(str).str.zfill(5)
trash = trash[trash['Request'] != 'Damage to Property']

missed_categories = ['Trash - Backdoor', 'Trash - Curbside/Alley Missed Pickup']

pattern = r"\bmiss\w*\b|not\s+emptied|not\s+picked\s+up|no\s+pick\s+up" #miss/missed, not emptied, not picked up, no pick up

if isinstance(missed_categories, list):
    missed_pattern = '|'.join(missed_categories)
else:
    missed_pattern = missed_categories 

mmissed = trash[
    (trash['Trash Hauler'].str.contains("Metro", case=False, na=False)) &
    (
        (trash['Request'].str.contains(missed_pattern, case=False, na=False)) |
        (trash['Description'].str.contains(pattern, case=False, na=False))
    )
]

mmissed = mmissed.dropna(subset = ['Incident Address']) # drop known missing address

# rrmissed = rrmissed.drop_duplicates(subset=['Incident Address', 'Date Opened']) # I believe this is redundancy and is taken care of later

def normalize_address(s: str) -> str:
    if pd.isna(s):
        return s
    # Only keep everything before the first comma
    s = s.split(",")[0]
    s = s.upper()
    s = re.sub(r"[.,]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    # (keep the direction/street type replacements here)
    return s

mmissed["address_norm"] = mmissed["Incident Address"].apply(normalize_address)

mmissed["Date Opened"] = pd.to_datetime(mmissed["Date Opened"], errors="coerce")
mmissed["date_only"] = mmissed["Date Opened"].dt.date

mmissed_dedup = (
    mmissed.sort_values(['address_norm', 'date_only', 'Date Opened'])
    .drop_duplicates(subset=['address_norm', 'date_only'], keep='first')
    .reset_index(drop=True)
)

gap = mmissed_dedup.groupby("address_norm")["Date Opened"].diff().dt.days
mmissed_dedup["new_event"] = (gap.isna()) | (gap > 6)
mmissed_dedup["event_id"]  = mmissed_dedup.groupby("address_norm")["new_event"].cumsum()

grp = mmissed_dedup.groupby(['address_norm', "event_id"])['Date Opened']
mmissed_dedup["event_date"]     = grp.transform("min")     

mmissed_dedup["event_seq"] = mmissed_dedup["event_id"].astype("Int64")

mmissed_dedup["fine_event"] = (mmissed_dedup["event_seq"] > 1).astype(int) * 200

mmissed_dedup["first_event"] = (mmissed_dedup['Date Opened'] == mmissed_dedup["event_date"])
mmissed_dedup["fine_event"] = mmissed_dedup["fine_event"].where(mmissed_dedup["first_event"], 0)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13256\2308983292.py:39: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   mmissed["Date Opened"] = pd.to_datetime(mmissed["Date Opened"], errors="coerce")

# %%
mmissed_dedup
# Out:
#       Request Number Date Opened                               Request  \
# 0              79395  2018-06-29  Trash - Curbside/Alley Missed Pickup
# 1              79884  2018-07-02  Trash - Curbside/Alley Missed Pickup
# 2             257588  2019-10-10  Trash - Curbside/Alley Missed Pickup
# 3             266788  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 4             253133  2019-09-30  Trash - Curbside/Alley Missed Pickup
# ...              ...         ...                                   ...
# 3041          149959  2019-03-04  Trash - Curbside/Alley Missed Pickup
# 3042          224867  2019-08-02  Trash - Curbside/Alley Missed Pickup
# 3043          226241  2019-08-06  Trash - Curbside/Alley Missed Pickup
# 3044          128671  2019-01-07  Trash - Curbside/Alley Missed Pickup
# 3045           88260  2018-08-06  Trash - Curbside/Alley Missed Pickup
#
#                                             Description  \
# 0                          the entire street was missed
# 1     Missed entire street- carts are curbside in fr...
# 2                             miss. driveway is on 14th
# 3                     missed 102 marshall court as well
# 4                                         MISSED- ALLEY
# ...                                                 ...
# 3041                           entire street was missed
# 3042  ENTIRE STREET AND SURROUNDING STREETS SUCH AS ...
# 3043  I called 311 on 2 AUgust and filed a missed ga...
# 3044                     Missed...along with neighbors.
# 3045                                    Did not pick up
#
#                                        Incident Address Zip Code Trash Hauler  \
# 0                                 1 BELLE FORREST AVE C    37206        METRO
# 1                                  10 Belle Forrest Ave    37206        METRO
# 2     100 Marshall Ct, Nashville, TN 37212, United S...    37212        METRO
# 3     100 Marshall Ct, Nashville, TN 37212, United S...    37212        METRO
# 4     1000 Gilmore Ave, Nashville, TN 37204, United ...    37204        METRO
# ...                                                 ...      ...          ...
# 3041  961 16th Ave N, Nashville, TN 37208, United St...    37208        METRO
# 3042  965 9th Ave S, Nashville, TN 37203, United States    37203        METRO
# 3043  965 9th Ave S, Nashville, TN 37203, United States    37203        METRO
# 3044  994 Dozier Pl, Nashville, TN 37216, United States    37216        METRO
# 3045                                          Beech Ave    37115        METRO
#
#      Trash Route  Council District  State Plan X   State Plan Y  \
# 0           9502               7.0  1.751942e+06  677895.310490
# 1           9502               7.0  1.751718e+06  678077.934103
# 2           9407              19.0  1.735543e+06  660440.744955
# 3           9407              19.0  1.735543e+06  660440.744955
# 4           9403              17.0  1.736212e+06  652995.000671
# ...          ...               ...           ...            ...
# 3041        9208              19.0  1.731877e+06  668380.001408
# 3042        9407              17.0  1.737999e+06  660504.848803
# 3043        9407              17.0  1.737999e+06  660504.848803
# 3044        9507               5.0  1.748996e+06  681411.999519
# 3045        9401               7.0  1.757564e+06  696230.763977
#
#                address_norm   date_only  new_event  event_id event_date  \
# 0     1 BELLE FORREST AVE C  2018-06-29       True         1 2018-06-29
# 1      10 BELLE FORREST AVE  2018-07-02       True         1 2018-07-02
# 2           100 MARSHALL CT  2019-10-10       True         1 2019-10-10
# 3           100 MARSHALL CT  2019-11-01       True         2 2019-11-01
# 4          1000 GILMORE AVE  2019-09-30       True         1 2019-09-30
# ...                     ...         ...        ...       ...        ...
# 3041         961 16TH AVE N  2019-03-04       True         1 2019-03-04
# 3042          965 9TH AVE S  2019-08-02       True         1 2019-08-02
# 3043          965 9TH AVE S  2019-08-06      False         1 2019-08-02
# 3044          994 DOZIER PL  2019-01-07       True         1 2019-01-07
# 3045              BEECH AVE  2018-08-06       True         1 2018-08-06
#
#       event_seq  fine_event  first_event
# 0             1           0         True
# 1             1           0         True
# 2             1           0         True
# 3             2         200         True
# 4             1           0         True
# ...         ...         ...          ...
# 3041          1           0         True
# 3042          1           0         True
# 3043          1           0        False
# 3044          1           0         True
# 3045          1           0         True
#
# [3046 rows x 19 columns]

# %%
mmissed_final = mmissed_dedup[mmissed_dedup['new_event'] == True]
mmissed_final
# Out:
#       Request Number Date Opened                               Request  \
# 0              79395  2018-06-29  Trash - Curbside/Alley Missed Pickup
# 1              79884  2018-07-02  Trash - Curbside/Alley Missed Pickup
# 2             257588  2019-10-10  Trash - Curbside/Alley Missed Pickup
# 3             266788  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 4             253133  2019-09-30  Trash - Curbside/Alley Missed Pickup
# ...              ...         ...                                   ...
# 3040           40981  2018-01-22  Trash - Curbside/Alley Missed Pickup
# 3041          149959  2019-03-04  Trash - Curbside/Alley Missed Pickup
# 3042          224867  2019-08-02  Trash - Curbside/Alley Missed Pickup
# 3044          128671  2019-01-07  Trash - Curbside/Alley Missed Pickup
# 3045           88260  2018-08-06  Trash - Curbside/Alley Missed Pickup
#
#                                             Description  \
# 0                          the entire street was missed
# 1     Missed entire street- carts are curbside in fr...
# 2                             miss. driveway is on 14th
# 3                     missed 102 marshall court as well
# 4                                         MISSED- ALLEY
# ...                                                 ...
# 3040                                     missed pick up
# 3041                           entire street was missed
# 3042  ENTIRE STREET AND SURROUNDING STREETS SUCH AS ...
# 3044                     Missed...along with neighbors.
# 3045                                    Did not pick up
#
#                                        Incident Address Zip Code Trash Hauler  \
# 0                                 1 BELLE FORREST AVE C    37206        METRO
# 1                                  10 Belle Forrest Ave    37206        METRO
# 2     100 Marshall Ct, Nashville, TN 37212, United S...    37212        METRO
# 3     100 Marshall Ct, Nashville, TN 37212, United S...    37212        METRO
# 4     1000 Gilmore Ave, Nashville, TN 37204, United ...    37204        METRO
# ...                                                 ...      ...          ...
# 3040                                  950 strouse ave a    37206        METRO
# 3041  961 16th Ave N, Nashville, TN 37208, United St...    37208        METRO
# 3042  965 9th Ave S, Nashville, TN 37203, United States    37203        METRO
# 3044  994 Dozier Pl, Nashville, TN 37216, United States    37216        METRO
# 3045                                          Beech Ave    37115        METRO
#
#      Trash Route  Council District  State Plan X   State Plan Y  \
# 0           9502               7.0  1.751942e+06  677895.310490
# 1           9502               7.0  1.751718e+06  678077.934103
# 2           9407              19.0  1.735543e+06  660440.744955
# 3           9407              19.0  1.735543e+06  660440.744955
# 4           9403              17.0  1.736212e+06  652995.000671
# ...          ...               ...           ...            ...
# 3040        9503               5.0  1.747772e+06  678308.902742
# 3041        9208              19.0  1.731877e+06  668380.001408
# 3042        9407              17.0  1.737999e+06  660504.848803
# 3044        9507               5.0  1.748996e+06  681411.999519
# 3045        9401               7.0  1.757564e+06  696230.763977
#
#                address_norm   date_only  new_event  event_id event_date  \
# 0     1 BELLE FORREST AVE C  2018-06-29       True         1 2018-06-29
# 1      10 BELLE FORREST AVE  2018-07-02       True         1 2018-07-02
# 2           100 MARSHALL CT  2019-10-10       True         1 2019-10-10
# 3           100 MARSHALL CT  2019-11-01       True         2 2019-11-01
# 4          1000 GILMORE AVE  2019-09-30       True         1 2019-09-30
# ...                     ...         ...        ...       ...        ...
# 3040      950 STROUSE AVE A  2018-01-22       True         1 2018-01-22
# 3041         961 16TH AVE N  2019-03-04       True         1 2019-03-04
# 3042          965 9TH AVE S  2019-08-02       True         1 2019-08-02
# 3044          994 DOZIER PL  2019-01-07       True         1 2019-01-07
# 3045              BEECH AVE  2018-08-06       True         1 2018-08-06
#
#       event_seq  fine_event  first_event
# 0             1           0         True
# 1             1           0         True
# 2             1           0         True
# 3             2         200         True
# 4             1           0         True
# ...         ...         ...          ...
# 3040          1           0         True
# 3041          1           0         True
# 3042          1           0         True
# 3044          1           0         True
# 3045          1           0         True
#
# [2947 rows x 19 columns]

# %%
mmissed_final.to_csv('mmissed_final.csv', index = False)

# %%
total_fines = int(mmissed_filtered["fine_event"].sum())

events_fined = int(
    mmissed_final[mmissed_final['event_id'] != 1].drop_duplicates(['address_norm', "event_id"]).shape[0]
)

# %%
total_fines
# Out:
# 197400

# %%
events_fined
# Out:
# 987

# %%
mmissed_final.to_csv('mmissed_final.csv', index = False)

# %%
mmissed_final_fined = mmissed_final[mmissed_final['fine_event'] != 0]
mmissed_final_fined
# Out:
#       Request Number Date Opened                               Request  \
# 3             266788  2019-11-01  Trash - Curbside/Alley Missed Pickup
# 22             80210  2018-07-03            Trash Collection Complaint
# 27            209281  2019-07-02  Trash - Curbside/Alley Missed Pickup
# 42            158241  2019-03-22  Trash - Curbside/Alley Missed Pickup
# 44            252698  2019-09-27  Trash - Curbside/Alley Missed Pickup
# ...              ...         ...                                   ...
# 3026           88097  2018-08-06                      Trash - Backdoor
# 3027          158554  2019-03-22                      Trash - Backdoor
# 3028          165477  2019-04-05                      Trash - Backdoor
# 3029          211729  2019-07-08                      Trash - Backdoor
# 3031          229863  2019-08-12  Trash - Curbside/Alley Missed Pickup
#
#                                             Description  \
# 3                     missed 102 marshall court as well
# 22    Missed- trash 3 weeks - caller said missed all...
# 27    Alley/trash missed {Tuesday} seen truck but di...
# 42    i watched them drive by my house when i was ou...
# 44    missed trash pick up yesterday (thursday, sept...
# ...                                                 ...
# 3026  Missed backdoor pickup has missed for 2 weeks....
# 3027  Missed backdoor Trash/pickup has missed for 2 ...
# 3028                                      backdoor miss
# 3029                              backdoor miss. 2 week
# 3031               Trash/missed curb {Friday} last week
#
#                                        Incident Address Zip Code Trash Hauler  \
# 3     100 Marshall Ct, Nashville, TN 37212, United S...    37212        METRO
# 22                                        1005 N 6th St    37207        METRO
# 27    1006 Pennock Ave, Nashville, TN 37207, United ...    37207        METRO
# 42                               1009 14TH AVE S, 37212    37212        METRO
# 44    1009 14th Ave S, Nashville, TN 37212, United S...    37212        METRO
# ...                                                 ...      ...          ...
# 3026                                      936 Cahal Ave    37206        METRO
# 3027                                      936 Cahal Ave    37206        METRO
# 3028  936 Cahal Ave, Nashville, TN 37206, United States    37206        METRO
# 3029  936 Cahal Ave, Nashville, TN 37206, United States    37206        METRO
# 3031  936 Strouse Ave, Nashville, TN 37206, United S...    37206        METRO
#
#      Trash Route  Council District  State Plan X   State Plan Y  \
# 3           9407              19.0  1.735543e+06  660440.744955
# 22          9203               5.0  1.743884e+06  676228.900673
# 27          9204               5.0  1.742195e+06  676283.198953
# 42          9407              19.0  1.735463e+06  660708.662868
# 44          9407              19.0  1.735463e+06  660708.662868
# ...          ...               ...           ...            ...
# 3026        9507               5.0  1.748204e+06  679278.132847
# 3027        9507               5.0  1.748206e+06  679274.398565
# 3028        9507               5.0  1.748206e+06  679274.398565
# 3029        9507               5.0  1.748206e+06  679274.398565
# 3031        9503               5.0  1.747431e+06  678349.598253
#
#           address_norm   date_only  new_event  event_id event_date  event_seq  \
# 3      100 MARSHALL CT  2019-11-01       True         2 2019-11-01          2
# 22       1005 N 6TH ST  2018-07-03       True         2 2018-07-03          2
# 27    1006 PENNOCK AVE  2019-07-02       True         2 2019-07-02          2
# 42     1009 14TH AVE S  2019-03-22       True         2 2019-03-22          2
# 44     1009 14TH AVE S  2019-09-27       True         3 2019-09-27          3
# ...                ...         ...        ...       ...        ...        ...
# 3026     936 CAHAL AVE  2018-08-06       True         5 2018-08-06          5
# 3027     936 CAHAL AVE  2019-03-22       True         6 2019-03-22          6
# 3028     936 CAHAL AVE  2019-04-05       True         7 2019-04-05          7
# 3029     936 CAHAL AVE  2019-07-08       True         8 2019-07-08          8
# 3031   936 STROUSE AVE  2019-08-12       True         2 2019-08-12          2
#
#       fine_event  first_event
# 3            200         True
# 22           200         True
# 27           200         True
# 42           200         True
# 44           200         True
# ...          ...          ...
# 3026         200         True
# 3027         200         True
# 3028         200         True
# 3029         200         True
# 3031         200         True
#
# [987 rows x 19 columns]

# %%
mmissed_final_fined.to_csv('mmissed_final_fined.csv', index = False)
